# %% [markdown]
# # Embedding
# mathmetical representation of words

# %%
import gensim

# %%
from gensim.models import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('./dataset/dataset/word2vec.6B.200d.txt')

# %%
model.most_similar(positive= ['person', 'queen'], negative=['king'])
# Out:
# [('woman', 0.6354276537895203),
#  ('someone', 0.5549800992012024),
#  ('she', 0.5433660745620728),
#  ('herself', 0.5216142535209656),
#  ('her', 0.5083276629447937),
#  ('anyone', 0.5072499513626099),
#  ('persons', 0.5012387633323669),
#  ('one', 0.49033915996551514),
#  ('child', 0.48775848746299744),
#  ('every', 0.4856557548046112)]

# %%
model.similar_by_word('marvel')
# Out:
# [('comics', 0.766106128692627),
#  ('superhero', 0.6700377464294434),
#  ('superheroes', 0.6589516401290894),
#  ('superman', 0.6061909198760986),
#  ('comic', 0.5999482274055481),
#  ('x-men', 0.5982449054718018),
#  ('spider-man', 0.5939557552337646),
#  ('universe', 0.5562811493873596),
#  ('batman', 0.5428684949874878),
#  ('team-up', 0.5420282483100891)]

# %%
import numpy as np
import pandas as pd
import nltk
import joblib

# %%
df = pd.read_csv('./dataset/dataset/imdb_labelled.txt', sep= '\t', header=None, names=['Review', 'Sentiment'])
df.head()
# Out:
#                                               Review  Sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
df.shape
# Out:
# (748, 2)

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (745, 2)

# %%
X= df['Review']
y= df['Sentiment']

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences  # padding helps to give same number of input to the model

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(X)

# %%
vocab_size = len(tokenizer.word_counts.keys())
vocab_size
# Out:
# 3133

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('a', 433),
#              ('very', 65),
#              ('slow', 6),
#              ('moving', 4),
#              ('aimless', 1),
#              ('movie', 181),
#              ('about', 50),
#              ('distressed', 1),
#              ('drifting', 1),
#              ('young', 4),
#              ('man', 13),
#              ('not', 72),
#              ('sure', 3),
#              ('who', 38),
#              ('was', 185),
#              ('more', 31),
#              ('lost', 4),
#              ('the', 848),
#              ('flat', 2),
#              ('characters', 35),
#              ('or', 41),
#              ('audience', 5),
#              ('nearly', 1),
#              ('half', 6),
#              ('of', 377),
#              ('whom', 2),
#              ('walked', 2),
#              ('out', 41),
#              ('attempting', 1),
#              ('artiness', 1),
#              ('with', 90),
#              ('black', 9),
#              ('white', 8),
#              ('and', 434),
#              ('clever', 5),
#              ('camera', 10),
#              ('angles', 2),
#              ('disappointed', 6),
#              ('became', 2),
#              ('even', 40),
#              ('ridiculous', 5),
#              ('as', 94),
#              ('acting', 43),
#              ('poor', 6),
#              ('plot', 28),
#              ('lines', 7),
#              ('almost', 9),
#              ('non', 5),
#              ('existent', 1),
#              ('little', 17),
#              ('music', 14),
#              ('anything', 8),
#              ('to', 253),
#              ('speak', 3),
#              ('best', 25),
#              ('scene', 14),
#              ('in', 203),
#              ('when', 29),
#              ('gerardo', 1),
#              ('is', 339),
#              ('trying', 4),
#              ('find', 10),
#              ('song', 4),
#              ('that', 156),
#              ('keeps', 2),
#              ('running', 2),
#              ('through', 10),
#              ('his', 42),
#              ('head', 3),
#              ('rest', 4),
#              ('lacks', 6),
#              ('art', 13),
#              ('charm', 2),
#              ('meaning', 3),
#              ('if', 45),
#              ("it's", 69),
#              ('emptiness', 1),
#              ('it', 256),
#              ('works', 5),
#              ('i', 270),
#              ('guess', 5),
#              ('because', 25),
#              ('empty', 2),
#              ('wasted', 7),
#              ('two', 13),
#              ('hours', 4),
#              ('saw', 12),
#              ('today', 3),
#              ('thought', 12),
#              ('good', 58),
#              ('effort', 1),
#              ('messages', 1),
#              ('for', 105),
#              ('kids', 8),
#              ('bit', 5),
#              ('predictable', 10),
#              ('loved', 10),
#              ('casting', 6),
#              ('jimmy', 2),
#              ('buffet', 1),
#              ('science', 1),
#              ('teacher', 1),
#              ('those', 12),
#              ('baby', 1),
#              ('owls', 1),
#              ('were', 38),
#              ('adorable', 4),
#              ('showed', 3),
#              ('lot', 9),
#              ('florida', 1),
#              ('at', 55),
#              ('made', 27),
#              ('look', 19),
#              ('appealing', 2),
#              ('songs', 4),
#              ('muppets', 1),
#              ('so', 62),
#              ('hilarious', 6),
#              ('cool', 7),
#              ('this', 292),
#              ('right', 13),
#              ('on', 76),
#              ('case', 2),
#              ('delivers', 3),
#              ('everything', 16),
#              ('your', 25),
#              ('face', 5),
#              ('had', 20),
#              ('some', 27),
#              ('average', 3),
#              ('from', 46),
#              ('main', 3),
#              ('person', 1),
#              ('low', 5),
#              ('budget', 7),
#              ('you', 76),
#              ('clearly', 2),
#              ('can', 25),
#              ('see', 36),
#              ('review', 2),
#              ('long', 8),
#              ('overdue', 1),
#              ('since', 5),
#              ('consider', 4),
#              ('tale', 4),
#              ('sisters', 2),
#              ('be', 53),
#              ('single', 5),
#              ('greatest', 3),
#              ('film', 159),
#              ('ever', 29),
#              ("i'll", 4),
#              ('put', 5),
#              ('gem', 3),
#              ('up', 21),
#              ('against', 1),
#              ('any', 21),
#              ('terms', 2),
#              ('screenplay', 1),
#              ('cinematography', 10),
#              ('post', 1),
#              ('production', 5),
#              ('editing', 6),
#              ('directing', 9),
#              ('other', 23),
#              ('aspect', 2),
#              ('making', 6),
#              ('practically', 1),
#              ('perfect', 6),
#              ('all', 65),
#              ('them', 17),
#              ('\x96', 5),
#              ('true', 4),
#              ('masterpiece', 2),
#              ('sea', 3),
#              ('faux', 3),
#              ('masterpieces', 2),
#              ('structure', 1),
#              ('easily', 4),
#              ('most', 32),
#              ('tightly', 1),
#              ('constructed', 1),
#              ('history', 6),
#              ('cinema', 8),
#              ('1', 121),
#              ('think', 21),
#              ('no', 31),
#              ('where', 8),
#              ('something', 4),
#              ('vitally', 1),
#              ('important', 3),
#              ('occurs', 1),
#              ('every', 20),
#              ('minute', 4),
#              ('words', 3),
#              ('content', 1),
#              ('level', 4),
#              ('enough', 11),
#              ('fill', 1),
#              ('dozen', 1),
#              ('films', 24),
#              ('how', 32),
#              ('anyone', 15),
#              ('their', 15),
#              ('mind', 5),
#              ('ask', 2),
#              ('than', 24),
#              ('quite', 10),
#              ('simply', 10),
#              ('highest', 1),
#              ('superlative', 1),
#              ('form', 2),
#              ('imaginable', 2),
#              ('yes', 3),
#              ('does', 9),
#              ('require', 1),
#              ('rather', 6),
#              ('significant', 3),
#              ('amount', 5),
#              ('puzzle', 1),
#              ('solving', 1),
#              ('but', 93),
#              ('pieces', 2),
#              ('fit', 2),
#              ('together', 7),
#              ('create', 2),
#              ('beautiful', 11),
#              ('picture', 3),
#              ('short', 11),
#              ('certainly', 8),
#              ('pulls', 1),
#              ('punches', 1),
#              ('0', 140),
#              ('graphics', 3),
#              ('far', 7),
#              ('part', 11),
#              ('game', 9),
#              ('number', 1),
#              ('one', 78),
#              ('th', 1),
#              ('series', 8),
#              ('deserves', 2),
#              ('strong', 5),
#              ('love', 22),
#              ('an', 55),
#              ('insane', 1),
#              ('there', 51),
#              ('are', 75),
#              ('massive', 3),
#              ('levels', 2),
#              ('unlockable', 1),
#              ('just', 63),
#              ('waste', 14),
#              ('money', 6),
#              ('kind', 8),
#              ('properly', 1),
#              ('actually', 10),
#              ('time', 43),
#              ('crap', 6),
#              ('they', 26),
#              ('say', 13),
#              ('canada', 2),
#              ('fun', 5),
#              ('aye', 1),
#              ('rocks', 1),
#              ('buy', 2),
#              ('play', 9),
#              ('enjoy', 5),
#              ('pure', 3),
#              ('brilliance', 3),
#              ('flick', 6),
#              ('doomed', 1),
#              ('its', 24),
#              ('conception', 1),
#              ('idea', 4),
#              ('lame', 5),
#              ('take', 6),
#              ('minor', 1),
#              ('character', 23),
#              ('mediocre', 4),
#              ('pg', 4),
#              ('13', 2),
#              ('make', 22),
#              ('complete', 3),
#              ('sequel', 2),
#              ('while', 3),
#              ('changing', 1),
#              ('tone', 1),
#              ('rated', 2),
#              ('family', 6),
#              ("wasn't", 7),
#              ('least', 9),
#              ('interested', 2),
#              ('only', 30),
#              ('did', 11),
#              ('confirm', 1),
#              ('would', 23),
#              ('unfunny', 2),
#              ('generic', 1),
#              ('also', 25),
#              ('managed', 1),
#              ('give', 11),
#              ('away', 5),
#              ('entire', 6),
#              ("i'm", 10),
#              ('exaggerating', 1),
#              ('moment', 3),
#              ('point', 4),
#              ('joke', 2),
#              ('told', 3),
#              ('trailer', 1),
#              ('funny', 19),
#              ('talented', 3),
#              ('carrell', 1),
#              ("can't", 11),
#              ('save', 1),
#              ('co', 1),
#              ('stars', 3),
#              ("don't", 25),
#              ('fare', 1),
#              ('much', 20),
#              ('better', 18),
#              ('people', 14),
#              ('like', 48),
#              ('morgan', 2),
#              ('freeman', 1),
#              ('jonah', 2),
#              ('hill', 3),
#              ('ed', 3),
#              ('helms', 1),
#              ('story', 28),
#              ('itself', 4),
#              ('lazy', 2),
#              ('real', 21),
#              ('effects', 9),
#              ('work', 20),
#              ('presence', 2),
#              ('animals', 1),
#              ('integration', 1),
#              ('into', 17),
#              ('scenes', 19),
#              ('worst', 11),
#              ('obvious', 2),
#              ('blue', 1),
#              ('green', 1),
#              ('screen', 14),
#              ("i've", 11),
#              ('seen', 23),
#              ('whatever', 6),
#              ('cost', 2),
#              ("didn't", 22),
#              ('translate', 1),
#              ('quality', 3),
#              ("that's", 9),
#              ('succeeds', 1),
#              ('despite', 2),
#              ('perhaps', 4),
#              ('obviously', 3),
#              ('meagre', 1),
#              ('glad', 4),
#              ('go', 14),
#              ('choice', 2),
#              ('lesser', 2),
#              ('have', 49),
#              ('addition', 3),
#              ('having', 6),
#              ('lovely', 4),
#              ('written', 7),
#              ('french', 2),
#              ('cancan', 1),
#              ('boasts', 1),
#              ('cutest', 1),
#              ('leading', 1),
#              ('ladies', 1),
#              ('grace', 3),
#              ('hard', 4),
#              ('fall', 2),
#              ('over', 18),
#              ('heels', 1),
#              ('girl', 5),
#              ('negative', 3),
#              ('insipid', 1),
#              ('cause', 2),
#              ('regret', 2),
#              ('another', 7),
#              ('2', 4),
#              ('life', 12),
#              ('front', 2),
#              ('whiny', 2),
#              ('pointless', 3),
#              ('recommend', 13),
#              ('waiting', 1),
#              ('future', 2),
#              ('efforts', 1),
#              ('let', 4),
#              ('excellent', 16),
#              ('cast', 18),
#              ('line', 12),
#              ('performances', 6),
#              ('totally', 15),
#              ('believable', 6),
#              ('anne', 2),
#              ('heche', 1),
#              ('utterly', 4),
#              ('convincing', 4),
#              ('sam', 1),
#              ("shepard's", 1),
#              ('portrayal', 6),
#              ('gung', 1),
#              ('ho', 1),
#              ('marine', 1),
#              ('sobering', 1),
#              ('sat', 1),
#              ('riveted', 1),
#              ('tv', 8),
#              ('resounding', 1),
#              ('9', 2),
#              ('10', 27),
#              ('do', 22),
#              ('tom', 5),
#              ('hanks', 1),
#              ('actor', 10),
#              ('enjoyed', 9),
#              ('reading', 2),
#              ('book', 4),
#              ('my', 36),
#              ('children', 3),
#              ('annoying', 6),
#              ('voice', 2),
#              ('gives', 6),
#              ('me', 22),
#              ('feeling', 10),
#              ('fingernails', 1),
#              ('chalkboard', 1),
#              ('unnecessary', 1),
#              ('train', 1),
#              ('roller', 1),
#              ('coaster', 1),
#              ('absolutely', 9),
#              ('warmth', 2),
#              ('these', 9),
#              ('grates', 1),
#              ('nerves', 1),
#              ('improved', 1),
#              ('by', 49),
#              ('improvisation', 1),
#              ('actors', 19),
#              ('now', 10),
#              ('twice', 2),
#              ('worry', 1),
#              ('whether', 4),
#              ("they're", 4),
#              ('delivering', 2),
#              ('well', 35),
#              ('honestly', 2),
#              ('often', 5),
#              ('dialogue', 13),
#              ("doesn't", 12),
#              ('really', 41),
#              ('follow', 4),
#              ('surroundings', 1),
#              ('crackles', 1),
#              ('unpredictable', 2),
#              ('youthful', 1),
#              ('energy', 4),
#              ('found', 8),
#              ('concentrate', 1),
#              ('meanders', 1),
#              ('badly', 2),
#              ('generally', 4),
#              ('great', 41),
#              ('things', 12),
#              ("wouldn't", 3),
#              ('worth', 12),
#              ('though', 11),
#              ('suspense', 8),
#              ('builders', 1),
#              ('cross', 1),
#              ('g', 1),
#              ('especially', 8),
#              ('liked', 10),
#              ('cliche', 1),
#              ('choices', 1),
#              ('parents', 2),
#              ('movies', 29),
#              ('could', 21),
#              ('predict', 1),
#              ('dialog', 3),
#              ('verbatim', 1),
#              ('writing', 13),
#              ('selections', 1),
#              ('want', 6),
#              ('gross', 1),
#              ('chills', 1),
#              ('alexander', 2),
#              ('nevsky', 1),
#              ('he', 40),
#              ('amazing', 9),
#              ('artist', 2),
#              ('whoever', 1),
#              ('lived', 1),
#              ('pretentious', 4),
#              ('piece', 10),
#              ('s', 2),
#              ('planned', 1),
#              ('dodge', 1),
#              ('stratus', 1),
#              ('big', 10),
#              ('shots', 3),
#              ('gonna', 2),
#              ('help', 1),
#              ('makers', 1),
#              ("aren't", 3),
#              ('restrained', 1),
#              ('business', 2),
#              ('québec', 1),
#              ('first', 11),
#              ('given', 3),
#              ('years', 14),
#              ('needed', 2),
#              ('word', 5),
#              ('mouth', 2),
#              ('promote', 1),
#              ('overall', 5),
#              ('interesting', 12),
#              ('provoking', 3),
#              ('plus', 3),
#              ('paced', 3),
#              ('suited', 1),
#              ('relatively', 1),
#              ('run', 2),
#              ('gave', 5),
#              ('wind', 3),
#              ('lion', 3),
#              ('superbly', 2),
#              ('acted', 3),
#              ('classic', 6),
#              ('turned', 2),
#              ('pretty', 13),
#              ('decent', 3),
#              ('b', 2),
#              ('list', 2),
#              ('horror', 9),
#              ('definitely', 8),
#              ('checking', 2),
#              ('problem', 2),
#              ('script', 24),
#              ('horrendous', 1),
#              ('nothing', 14),
#              ('frustration', 1),
#              ('retarded', 1),
#              ('girls', 1),
#              ('manna', 1),
#              ('heaven', 2),
#              ('terrific', 5),
#              ('both', 15),
#              ('same', 5),
#              ('occasionally', 4),
#              ('touching', 3),
#              ('evaluate', 1),
#              ('lives', 2),
#              ('going', 10),
#              ('veteran', 1),
#              ('nostalgia', 1),
#              ('trip', 1),
#              ('ursula', 1),
#              ("burton's", 1),
#              ('nun', 1),
#              ('nuns', 1),
#              ('church', 2),
#              ('looking', 3),
#              ('including', 3),
#              ('shirley', 1),
#              ('jones', 1),
#              ('rendition', 1),
#              ('way', 23),
#              ('tonight', 1),
#              ('uplifting', 2),
#              ('ending', 11),
#              ('try', 4),
#              ('will', 21),
#              ('frankly', 2),
#              ('after', 13),
#              ('cotton', 1),
#              ('club', 1),
#              ('unfaithful', 1),
#              ('embarrassing', 3),
#              ('watch', 17),
#              ('lane', 2),
#              ('gere', 1),
#              ('bad', 71),
#              ('dialogs', 1),
#              ('extremely', 4),
#              ('shallow', 1),
#              ('insincere', 1),
#              ('too', 20),
#              ('chick', 2),
#              ('politically', 1),
#              ('correct', 1),
#              ('disappointing', 2),
#              ('thing', 13),
#              ('watching', 22),
#              ('scenery', 3),
#              ('house', 3),
#              ('never', 18),
#              ('her', 22),
#              ('lousy', 2),
#              ('hour', 5),
#              ('wish', 3),
#              ('bring', 2),
#              ('back', 4),
#              ('fresh', 2),
#              ('bold', 2),
#              ('helps', 2),
#              ('along', 3),
#              ('maybe', 4),
#              ('idiot', 2),
#              ('savant', 1),
#              ('sister', 1),
#              ('been', 12),
#              ('played', 10),
#              ('joy', 5),
#              ('boring', 10),
#              ('sometimes', 4),
#              ('myself', 8),
#              ('occupied', 2),
#              ('peaking', 1),
#              ('paper', 1),
#              ('instead', 2),
#              ('happened', 3),
#              ('during', 4),
#              ('columbo', 1),
#              ('before', 5),
#              ('seems', 3),
#              ('oh', 5),
#              ('mature', 3),
#              ('neighbour', 1),
#              ('misplace', 1),
#              ('weaker', 1),
#              ('episode', 3),
#              ('then', 8),
#              ('debated', 1),
#              ('sack', 1),
#              ('trumpeter', 1),
#              ('falsely', 1),
#              ('accused', 2),
#              ('murder', 1),
#              ('stupid', 14),
#              ('applause', 1),
#              ('should', 11),
#              ('prelude', 1),
#              ('however', 10),
#              ('director', 10),
#              ('edge', 2),
#              ('seat', 1),
#              ('somewhat', 2),
#              ('afraid', 2),
#              ('car', 1),
#              ('end', 11),
#              ('night', 5),
#              ('nice', 6),
#              ("i'd", 6),
#              ('advise', 2),
#              ('brilliant', 6),
#              ('playing', 7),
#              ('villain', 1),
#              ('rent', 6),
#              ('michael', 1),
#              ('ironside', 1),
#              ('rocked', 1),
#              ('world', 6),
#              ('must', 7),
#              ('social', 1),
#              ('physical', 1),
#              ('outlets', 1),
#              ('fact', 8),
#              ('tremendously', 2),
#              ('chemistry', 4),
#              ('between', 10),
#              ('ben', 1),
#              ('affleck', 1),
#              ('sandra', 2),
#              ('bullock', 2),
#              ("couldn't", 5),
#              ('understand', 9),
#              ('why', 6),
#              ('leaving', 1),
#              ('wife', 1),
#              ('supposedly', 2),
#              ('knocked', 1),
#              ('several', 2),
#              ('moments', 2),
#              ('need', 2),
#              ('excruciatingly', 1),
#              ('remake', 3),
#              ('friends', 2),
#              ('wedding', 1),
#              ('disappointment', 2),
#              ('cannot', 2),
#              ('believe', 8),
#              ('agreed', 1),
#              ('stand', 2),
#              ('fear', 3),
#              ('losing', 2),
#              ('q', 1),
#              ('nobody', 3),
#              ('network', 1),
#              ('aired', 1),
#              ('dribble', 1),
#              ('watched', 9),
#              ('putting', 2),
#              ('imdb', 1),
#              ('ratings', 2),
#              ('awful', 14),
#              ('get', 14),
#              ('numbers', 1),
#              ('cases', 1),
#              ('such', 12),
#              ('mirrormask', 1),
#              ('last', 4),
#              ('unsatisfactory', 1),
#              ('experience', 7),
#              ('unfortunately', 4),
#              ('inexperience', 1),
#              ('direction', 5),
#              ('meant', 1),
#              ('passed', 1),
#              ('dramatic', 2),
#              ('tension', 2),
#              ('conflict', 3),
#              ('central', 2),
#              ('themes', 2),
#              ('handled', 2),
#              ('ineptly', 1),
#              ('stereotypically', 1),
#              ('depth', 4),
#              ('imagination', 4),
#              ('pictures', 2),
#              ('flawed', 2),
#              ('core', 2),
#              ('following', 2),
#              ('bunch', 2),
#              ('high', 2),
#              ('schoolers', 1),
#              ('whine', 1),
#              ('cry', 1),
#              ('relate', 1),
#              ('hell', 2),
#              ('barely', 4),
#              ('cult', 5),
#              ('viewing', 2),
#              ('sharing', 1),
#              ('others', 1),
#              ('disaster', 2),
#              ('confuses', 1),
#              ('incredibly', 3),
#              ('fish', 1),
#              ('underwater', 1),
#              ('repeated', 1),
#              ('thousand', 1),
#              ('times', 5),
#              ('truly', 9),
#              ('terrible', 12),
#              ('worse', 11),
#              ('possible', 3),
#              ('redeemed', 1),
#              ('mst3k', 1),
#              ('fodder', 1),
#              ('paid', 2),
#              ('treat', 1),
#              ('anthony', 1),
#              ('quinn', 2),
#              ('crazy', 2),
#              ('horse', 1),
#              ('whatsoever', 3),
#              ('again', 13),
#              ('horrible', 6),
#              ('gosh', 1),
#              ('walk', 1),
#              ('theatre', 1),
#              ('few', 6),
#              ('minutes', 8),
#              ('relief', 1),
#              ('hate', 2),
#              ('yeah', 2),
#              ('sucked', 7),
#              ('storyline', 4),
#              ('pillow', 1),
#              ('girlfriend', 2),
#              ('boyfriend', 1),
#              ('keep', 4),
#              ('gone', 1),
#              ('disliked', 2),
#              ('tickets', 1),
#              ('five', 2),
#              ('dollars', 1),
#              ('mad', 2),
#              ('7', 1),
#              ('50', 2),
#              ('identifies', 1),
#              ('cardboard', 2),
#              ('cutouts', 1),
#              ('stereotypes', 3),
#              ('predictably', 2),
#              ('reverse', 1),
#              ('ugly', 1),
#              ('cartoon', 3),
#              ('crafted', 2),
#              ('paul', 3),
#              ('haggis', 1),
#              ('handle', 1),
#              ('strokes', 1),
#              ('storytelling', 1),
#              ('painted', 1),
#              ('crayons', 1),
#              ('crash', 1),
#              ('depressing', 2),
#              ('provokes', 1),
#              ('emotion', 1),
#              ('teaches', 1),
#              ('already', 4),
#              ('know', 14),
#              ('racism', 2),
#              ('prejudice', 1),
#              ('still', 14),
#              ('empowerment', 1),
#              ('women', 3),
#              ("there's", 8),
#              ('brain', 3),
#              ('attempt', 4),
#              ('shut', 1),
#              ('down', 4),
#              ('primal', 1),
#              ('impulse', 1),
#              ('self', 7),
#              ('preservation', 1),
#              ('left', 3),
#              ('shattered', 1),
#              ("'film'", 1),
#              ('took', 2),
#              ('fully', 1),
#              ('recover', 1),
#              ('joins', 1),
#              ('revenge', 1),
#              ('boogeyman', 1),
#              ('zombiez', 1),
#              ('hellish', 1),
#              ('trinity', 1),
#              ('mean', 4),
#              ('distinction', 1),
#              ('has', 38),
#              ('redeeming', 2),
#              ('features', 3),
#              ('appalling', 2),
#              ('artless', 1),
#              ('endlessly', 1),
#              ('presents', 3),
#              ('us', 4),
#              ('ugliest', 1),
#              ('setting', 2),
#              ('e', 1),
#              ('beyond', 5),
#              ('is\x85was', 1),
#              ('lead', 5),
#              ('charisma', 2),
#              ('free', 3),
#              ('without', 4),
#              ('merit', 1),
#              ('akin', 1),
#              ('torture', 4),
#              ('reasonable', 1),
#              ('explanation', 2),
#              ('atrocity', 1),
#              ('pleasant', 1),
#              ('voyage', 1),
#              ('discovery', 1),
#              ('highly', 10),
#              ('unrecommended', 1),
#              ('premise', 4),
#              ('sound', 6),
#              ('performance', 12),
#              ('ms', 1),
#              ('garbo', 1),
#              ('off', 10),
#              ('bat', 1),
#              ('talents', 1),
#              ('carry', 1),
#              ('silent', 5),
#              ('era', 2),
#              ('wanted', 2),
#              ('netflix', 1),
#              ('seem', 4),
#              ('stocking', 1),
#              ('renowned', 1),
#              ('screenwriter', 3),
#              ('frances', 1),
#              ('marion', 1),
#              ("hasn't", 1),
#              ('missed', 2),
#              ('step', 2),
#              ('suffered', 1),
#              ('many', 14),
#              ('close', 3),
#              ('ups', 4),
#              ('seemed', 3),
#              ('drag', 1),
#              ('heroes', 1),
#              ('freedom', 2),
#              ('below', 2),
#              ("you'll", 3),
#              ('ones', 1),
#              ('received', 2),
#              ('age', 4),
#              ('john', 7),
#              ('wayne', 2),
#              ('incredible', 6),
#              ('job', 9),
#              ('being', 12),
#              ('industry', 2),
#              ('shined', 1),
#              ('senior', 1),
#              ('him', 6),
#              ('older', 1),
#              ('indulgent', 3),
#              ('junk', 1),
#              ('probably', 8),
#              ("hadn't", 1),
#              ('spent', 3),
#              ('showcasing', 1),
#              ('own', 6),
#              ('which', 22),
#              ("isn't", 3),
#              ('noteworthy', 2),
#              ('got', 8),
#              ('punched', 1),
#              ('gallon', 1),
#              ('blood', 2),
#              ('spew', 1),
#              ('forth', 1),
#              ('soon', 1),
#              ('jamie', 2),
#              ('foxx', 1),
#              ('ray', 4),
#              ('charles', 3),
#              ('genius', 2),
#              ('owns', 1),
#              ('spacek', 1),
#              ('owned', 2),
#              ('coal', 1),
#              ("miner's", 1),
#              ('daughter', 2),
#              ('quaid', 1),
#              ('balls', 1),
#              ('fire', 1),
#              ('remember', 3),
#              ('himself', 1),
#              ('legendary', 1),
#              ("charles'", 1),
#              ('provided', 1),
#              ('biographical', 1),
#              ('material', 2),
#              ('goes', 2),
#              ('musician', 1),
#              ('hitchcock', 5),
#              ('ironically', 1),
#              ('mostly', 6),
#              ('total', 1),
#              ('secondly', 1),
#              ('perfected', 1),
#              ('thriller', 5),
#              ('chase', 1),
#              ('pandering', 1),
#              ('sabotages', 1),
#              ('hence', 2),
#              ('whole', 9),
#              ('certain', 1),
#              ('rumbles', 1),
#              ('machine', 2),
#              ('desperately', 1),
#              ('depending', 1),
#              ('new', 5),
#              ('usual', 4),
#              ('logic', 1),
#              ('flaws', 2),
#              ('mishima', 2),
#              ('uninteresting', 2),
#              ('chilly', 2),
#              ('unremarkable', 1),
#              ('author', 1),
#              ('living', 4),
#              ('working', 3),
#              ('abstruse', 1),
#              ('culture', 1),
#              ('reenactments', 1),
#              ('hold', 1),
#              ('attention', 3),
#              ('emotionally', 1),
#              ('adrift', 1),
#              ('stagy', 1),
#              ('sits', 1),
#              ...])

# %%
word_index = tokenizer.word_index
word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'a': 3,
#  'of': 4,
#  'is': 5,
#  'this': 6,
#  'i': 7,
#  'it': 8,
#  'to': 9,
#  'in': 10,
#  'was': 11,
#  'movie': 12,
#  'film': 13,
#  'that': 14,
#  '0': 15,
#  '1': 16,
#  'for': 17,
#  'as': 18,
#  'but': 19,
#  'with': 20,
#  'one': 21,
#  'on': 22,
#  'you': 23,
#  'are': 24,
#  'not': 25,
#  'bad': 26,
#  "it's": 27,
#  'very': 28,
#  'all': 29,
#  'just': 30,
#  'so': 31,
#  'good': 32,
#  'at': 33,
#  'an': 34,
#  'be': 35,
#  'there': 36,
#  'about': 37,
#  'have': 38,
#  'by': 39,
#  'like': 40,
#  'from': 41,
#  'if': 42,
#  'acting': 43,
#  'time': 44,
#  'his': 45,
#  'or': 46,
#  'out': 47,
#  'really': 48,
#  'great': 49,
#  'even': 50,
#  'he': 51,
#  'who': 52,
#  'were': 53,
#  'has': 54,
#  'see': 55,
#  'my': 56,
#  'characters': 57,
#  'well': 58,
#  'most': 59,
#  'how': 60,
#  'more': 61,
#  'no': 62,
#  'only': 63,
#  'when': 64,
#  'ever': 65,
#  'movies': 66,
#  'plot': 67,
#  'story': 68,
#  'made': 69,
#  'some': 70,
#  '10': 71,
#  'they': 72,
#  'best': 73,
#  'because': 74,
#  'your': 75,
#  'can': 76,
#  'also': 77,
#  "don't": 78,
#  'films': 79,
#  'than': 80,
#  'its': 81,
#  'script': 82,
#  'other': 83,
#  'character': 84,
#  'would': 85,
#  'seen': 86,
#  'way': 87,
#  'love': 88,
#  'make': 89,
#  "didn't": 90,
#  'do': 91,
#  'me': 92,
#  'watching': 93,
#  'her': 94,
#  'which': 95,
#  'what': 96,
#  'up': 97,
#  'any': 98,
#  'think': 99,
#  'real': 100,
#  'could': 101,
#  'will': 102,
#  'had': 103,
#  'every': 104,
#  'much': 105,
#  'work': 106,
#  'too': 107,
#  'look': 108,
#  'funny': 109,
#  'scenes': 110,
#  'actors': 111,
#  'better': 112,
#  'over': 113,
#  'cast': 114,
#  'never': 115,
#  'wonderful': 116,
#  'little': 117,
#  'them': 118,
#  'into': 119,
#  'watch': 120,
#  'show': 121,
#  'everything': 122,
#  'excellent': 123,
#  'anyone': 124,
#  'their': 125,
#  'totally': 126,
#  'both': 127,
#  'here': 128,
#  'music': 129,
#  'scene': 130,
#  'waste': 131,
#  'people': 132,
#  'screen': 133,
#  'go': 134,
#  'years': 135,
#  'nothing': 136,
#  'stupid': 137,
#  'awful': 138,
#  'get': 139,
#  'know': 140,
#  'still': 141,
#  'many': 142,
#  'man': 143,
#  'art': 144,
#  'two': 145,
#  'right': 146,
#  'say': 147,
#  'recommend': 148,
#  'dialogue': 149,
#  'writing': 150,
#  'pretty': 151,
#  'after': 152,
#  'thing': 153,
#  'again': 154,
#  'saw': 155,
#  'thought': 156,
#  'those': 157,
#  'life': 158,
#  'line': 159,
#  "doesn't": 160,
#  'things': 161,
#  'worth': 162,
#  'interesting': 163,
#  'been': 164,
#  'such': 165,
#  'terrible': 166,
#  'performance': 167,
#  'being': 168,
#  'enough': 169,
#  'beautiful': 170,
#  'short': 171,
#  'part': 172,
#  'did': 173,
#  'give': 174,
#  "can't": 175,
#  'worst': 176,
#  "i've": 177,
#  'though': 178,
#  'first': 179,
#  'ending': 180,
#  'should': 181,
#  'end': 182,
#  'worse': 183,
#  'she': 184,
#  'camera': 185,
#  'find': 186,
#  'through': 187,
#  'predictable': 188,
#  'loved': 189,
#  'cinematography': 190,
#  'quite': 191,
#  'simply': 192,
#  'actually': 193,
#  "i'm": 194,
#  'actor': 195,
#  'feeling': 196,
#  'now': 197,
#  'liked': 198,
#  'piece': 199,
#  'big': 200,
#  'going': 201,
#  'played': 202,
#  'boring': 203,
#  'however': 204,
#  'director': 205,
#  'between': 206,
#  'highly': 207,
#  'off': 208,
#  'drama': 209,
#  'black': 210,
#  'almost': 211,
#  'lot': 212,
#  'directing': 213,
#  'does': 214,
#  'game': 215,
#  'play': 216,
#  'least': 217,
#  'effects': 218,
#  "that's": 219,
#  'enjoyed': 220,
#  'absolutely': 221,
#  'these': 222,
#  'amazing': 223,
#  'horror': 224,
#  'understand': 225,
#  'watched': 226,
#  'truly': 227,
#  'job': 228,
#  'whole': 229,
#  'we': 230,
#  'am': 231,
#  'special': 232,
#  'white': 233,
#  'anything': 234,
#  'kids': 235,
#  'long': 236,
#  'cinema': 237,
#  'where': 238,
#  'certainly': 239,
#  'series': 240,
#  'kind': 241,
#  'tv': 242,
#  'found': 243,
#  'suspense': 244,
#  'especially': 245,
#  'definitely': 246,
#  'myself': 247,
#  'then': 248,
#  'fact': 249,
#  'believe': 250,
#  'minutes': 251,
#  "there's": 252,
#  'probably': 253,
#  'got': 254,
#  'used': 255,
#  'done': 256,
#  'old': 257,
#  'makes': 258,
#  'mess': 259,
#  'avoid': 260,
#  'sucks': 261,
#  'lines': 262,
#  'wasted': 263,
#  'cool': 264,
#  'budget': 265,
#  'together': 266,
#  'far': 267,
#  "wasn't": 268,
#  'written': 269,
#  'another': 270,
#  'playing': 271,
#  'must': 272,
#  'experience': 273,
#  'sucked': 274,
#  'self': 275,
#  'john': 276,
#  'action': 277,
#  'cheap': 278,
#  'subtle': 279,
#  'everyone': 280,
#  'our': 281,
#  'around': 282,
#  'each': 283,
#  'top': 284,
#  'garbage': 285,
#  'comedy': 286,
#  'slow': 287,
#  'half': 288,
#  'disappointed': 289,
#  'poor': 290,
#  'lacks': 291,
#  'casting': 292,
#  'hilarious': 293,
#  'editing': 294,
#  'making': 295,
#  'perfect': 296,
#  'history': 297,
#  'rather': 298,
#  'money': 299,
#  'crap': 300,
#  'flick': 301,
#  'take': 302,
#  'family': 303,
#  'entire': 304,
#  'whatever': 305,
#  'having': 306,
#  'performances': 307,
#  'believable': 308,
#  'portrayal': 309,
#  'annoying': 310,
#  'gives': 311,
#  'want': 312,
#  'classic': 313,
#  'nice': 314,
#  "i'd": 315,
#  'brilliant': 316,
#  'rent': 317,
#  'world': 318,
#  'why': 319,
#  'horrible': 320,
#  'few': 321,
#  'sound': 322,
#  'incredible': 323,
#  'him': 324,
#  'own': 325,
#  'mostly': 326,
#  'holes': 327,
#  'use': 328,
#  'human': 329,
#  'memorable': 330,
#  'seeing': 331,
#  'gets': 332,
#  'throughout': 333,
#  'second': 334,
#  'style': 335,
#  'audience': 336,
#  'clever': 337,
#  'ridiculous': 338,
#  'non': 339,
#  'works': 340,
#  'guess': 341,
#  'bit': 342,
#  'face': 343,
#  'low': 344,
#  'since': 345,
#  'single': 346,
#  'put': 347,
#  'production': 348,
#  '\x96': 349,
#  'mind': 350,
#  'amount': 351,
#  'strong': 352,
#  'fun': 353,
#  'enjoy': 354,
#  'lame': 355,
#  'away': 356,
#  'girl': 357,
#  'tom': 358,
#  'often': 359,
#  'word': 360,
#  'overall': 361,
#  'gave': 362,
#  'terrific': 363,
#  'same': 364,
#  'hour': 365,
#  'joy': 366,
#  'before': 367,
#  'oh': 368,
#  'night': 369,
#  "couldn't": 370,
#  'direction': 371,
#  'cult': 372,
#  'times': 373,
#  'beyond': 374,
#  'lead': 375,
#  'silent': 376,
#  'hitchcock': 377,
#  'thriller': 378,
#  'new': 379,
#  'full': 380,
#  'completely': 381,
#  'pathetic': 382,
#  'talk': 383,
#  'care': 384,
#  'fails': 385,
#  'yet': 386,
#  'said': 387,
#  'fans': 388,
#  'solid': 389,
#  'felt': 390,
#  'child': 391,
#  'day': 392,
#  'started': 393,
#  'shot': 394,
#  'mention': 395,
#  'year': 396,
#  'different': 397,
#  'involved': 398,
#  'period': 399,
#  "won't": 400,
#  'particularly': 401,
#  'come': 402,
#  'superb': 403,
#  'fine': 404,
#  'recommended': 405,
#  'fast': 406,
#  'moving': 407,
#  'young': 408,
#  'lost': 409,
#  'trying': 410,
#  'song': 411,
#  'rest': 412,
#  'hours': 413,
#  'adorable': 414,
#  'songs': 415,
#  'consider': 416,
#  'tale': 417,
#  "i'll": 418,
#  'true': 419,
#  'easily': 420,
#  'something': 421,
#  'minute': 422,
#  'level': 423,
#  'idea': 424,
#  'mediocre': 425,
#  'pg': 426,
#  'point': 427,
#  'itself': 428,
#  'perhaps': 429,
#  'glad': 430,
#  'lovely': 431,
#  'hard': 432,
#  '2': 433,
#  'let': 434,
#  'utterly': 435,
#  'convincing': 436,
#  'book': 437,
#  'whether': 438,
#  "they're": 439,
#  'follow': 440,
#  'energy': 441,
#  'generally': 442,
#  'pretentious': 443,
#  'occasionally': 444,
#  'try': 445,
#  'extremely': 446,
#  'back': 447,
#  'maybe': 448,
#  'sometimes': 449,
#  'during': 450,
#  'chemistry': 451,
#  'last': 452,
#  'unfortunately': 453,
#  'depth': 454,
#  'imagination': 455,
#  'barely': 456,
#  'storyline': 457,
#  'keep': 458,
#  'already': 459,
#  'attempt': 460,
#  'down': 461,
#  'mean': 462,
#  'us': 463,
#  'without': 464,
#  'torture': 465,
#  'premise': 466,
#  'seem': 467,
#  'ups': 468,
#  'age': 469,
#  'ray': 470,
#  'usual': 471,
#  'living': 472,
#  'themselves': 473,
#  'else': 474,
#  'tell': 475,
#  'visual': 476,
#  'plain': 477,
#  'soundtrack': 478,
#  'trash': 479,
#  'came': 480,
#  'either': 481,
#  'less': 482,
#  'hope': 483,
#  'eyes': 484,
#  'indeed': 485,
#  'theater': 486,
#  'rating': 487,
#  'three': 488,
#  'huge': 489,
#  'intelligence': 490,
#  'intelligent': 491,
#  'entertaining': 492,
#  'bored': 493,
#  'become': 494,
#  'roles': 495,
#  'drago': 496,
#  'looked': 497,
#  'parts': 498,
#  'sets': 499,
#  'stories': 500,
#  'created': 501,
#  'role': 502,
#  'scamp': 503,
#  'comes': 504,
#  'place': 505,
#  'star': 506,
#  'always': 507,
#  'insult': 508,
#  'death': 509,
#  'may': 510,
#  'expect': 511,
#  'serious': 512,
#  'original': 513,
#  'james': 514,
#  'unbelievable': 515,
#  'costs': 516,
#  'small': 517,
#  'dance': 518,
#  'beginning': 519,
#  'appreciate': 520,
#  'easy': 521,
#  'sure': 522,
#  'speak': 523,
#  'head': 524,
#  'meaning': 525,
#  'today': 526,
#  'showed': 527,
#  'delivers': 528,
#  'average': 529,
#  'main': 530,
#  'greatest': 531,
#  'gem': 532,
#  'sea': 533,
#  'faux': 534,
#  'important': 535,
#  'words': 536,
#  'yes': 537,
#  'significant': 538,
#  'picture': 539,
#  'graphics': 540,
#  'massive': 541,
#  'pure': 542,
#  'brilliance': 543,
#  'complete': 544,
#  'while': 545,
#  'moment': 546,
#  'told': 547,
#  'talented': 548,
#  'stars': 549,
#  'hill': 550,
#  'ed': 551,
#  'quality': 552,
#  'obviously': 553,
#  'addition': 554,
#  'grace': 555,
#  'negative': 556,
#  'pointless': 557,
#  'children': 558,
#  "wouldn't": 559,
#  'dialog': 560,
#  'shots': 561,
#  "aren't": 562,
#  'given': 563,
#  'provoking': 564,
#  'plus': 565,
#  'paced': 566,
#  'wind': 567,
#  'lion': 568,
#  'acted': 569,
#  'decent': 570,
#  'touching': 571,
#  'looking': 572,
#  'including': 573,
#  'embarrassing': 574,
#  'scenery': 575,
#  'house': 576,
#  'wish': 577,
#  'along': 578,
#  'happened': 579,
#  'seems': 580,
#  'mature': 581,
#  'episode': 582,
#  'remake': 583,
#  'fear': 584,
#  'nobody': 585,
#  'conflict': 586,
#  'incredibly': 587,
#  'possible': 588,
#  'whatsoever': 589,
#  'stereotypes': 590,
#  'cartoon': 591,
#  'paul': 592,
#  'women': 593,
#  'brain': 594,
#  'left': 595,
#  'features': 596,
#  'presents': 597,
#  'free': 598,
#  'screenwriter': 599,
#  'close': 600,
#  'seemed': 601,
#  "you'll": 602,
#  'indulgent': 603,
#  'spent': 604,
#  "isn't": 605,
#  'charles': 606,
#  'remember': 607,
#  'working': 608,
#  'attention': 609,
#  'singing': 610,
#  'etc': 611,
#  'bore': 612,
#  'dancing': 613,
#  'dvd': 614,
#  'might': 615,
#  'theme': 616,
#  'aerial': 617,
#  'interest': 618,
#  'narrative': 619,
#  'actress': 620,
#  'called': 621,
#  'spoilers': 622,
#  'stunning': 623,
#  'fx': 624,
#  'note': 625,
#  'surprisingly': 626,
#  'released': 627,
#  'ranks': 628,
#  'journey': 629,
#  'location': 630,
#  'thoroughly': 631,
#  'turn': 632,
#  'memories': 633,
#  'places': 634,
#  'billy': 635,
#  'possibly': 636,
#  'trilogy': 637,
#  'favourite': 638,
#  'awesome': 639,
#  'earlier': 640,
#  'directed': 641,
#  'someone': 642,
#  'sense': 643,
#  'games': 644,
#  'genuine': 645,
#  'smart': 646,
#  "haven't": 647,
#  'particular': 648,
#  'stage': 649,
#  'next': 650,
#  '8': 651,
#  'super': 652,
#  'wonderfully': 653,
#  'actresses': 654,
#  'exactly': 655,
#  'shows': 656,
#  'drive': 657,
#  'scared': 658,
#  'enjoyable': 659,
#  'bought': 660,
#  '90': 661,
#  'god': 662,
#  'effective': 663,
#  'set': 664,
#  'learn': 665,
#  'values': 666,
#  'photography': 667,
#  'ruthless': 668,
#  'although': 669,
#  'war': 670,
#  'type': 671,
#  'example': 672,
#  'feel': 673,
#  'seriously': 674,
#  'ready': 675,
#  'fan': 676,
#  'angel': 677,
#  'under': 678,
#  'coming': 679,
#  '20': 680,
#  'charming': 681,
#  'clichés': 682,
#  'thrown': 683,
#  'reason': 684,
#  'scale': 685,
#  'problems': 686,
#  'score': 687,
#  'frightening': 688,
#  'oscar': 689,
#  'knew': 690,
#  'lots': 691,
#  'space': 692,
#  'footage': 693,
#  'course': 694,
#  'perfectly': 695,
#  'finally': 696,
#  'share': 697,
#  'rate': 698,
#  'sort': 699,
#  'conclusion': 700,
#  'heart': 701,
#  'race': 702,
#  'appearance': 703,
#  'looks': 704,
#  'happen': 705,
#  'final': 706,
#  'unconvincing': 707,
#  'produced': 708,
#  'early': 709,
#  'documentary': 710,
#  'martin': 711,
#  'racial': 712,
#  'mickey': 713,
#  'watchable': 714,
#  'weak': 715,
#  'due': 716,
#  "film's": 717,
#  'recent': 718,
#  "90's": 719,
#  'nonsense': 720,
#  'fantastic': 721,
#  'south': 722,
#  "you're": 723,
#  'plays': 724,
#  'thinking': 725,
#  'wrong': 726,
#  'giallo': 727,
#  'sub': 728,
#  'emotions': 729,
#  'ability': 730,
#  'write': 731,
#  'writer': 732,
#  'puppets': 733,
#  'animation': 734,
#  'flat': 735,
#  'whom': 736,
#  'walked': 737,
#  'angles': 738,
#  'became': 739,
#  'keeps': 740,
#  'running': 741,
#  'charm': 742,
#  'empty': 743,
#  'jimmy': 744,
#  'appealing': 745,
#  'case': 746,
#  'clearly': 747,
#  'review': 748,
#  'sisters': 749,
#  'terms': 750,
#  'aspect': 751,
#  'masterpiece': 752,
#  'masterpieces': 753,
#  'ask': 754,
#  'form': 755,
#  'imaginable': 756,
#  'pieces': 757,
#  'fit': 758,
#  'create': 759,
#  'deserves': 760,
#  'levels': 761,
#  'canada': 762,
#  'buy': 763,
#  '13': 764,
#  'sequel': 765,
#  'rated': 766,
#  'interested': 767,
#  'unfunny': 768,
#  'joke': 769,
#  'morgan': 770,
#  'jonah': 771,
#  'lazy': 772,
#  'presence': 773,
#  'obvious': 774,
#  'cost': 775,
#  'despite': 776,
#  'choice': 777,
#  'lesser': 778,
#  'french': 779,
#  'fall': 780,
#  'cause': 781,
#  'regret': 782,
#  'front': 783,
#  'whiny': 784,
#  'future': 785,
#  'anne': 786,
#  '9': 787,
#  'reading': 788,
#  'voice': 789,
#  'warmth': 790,
#  'twice': 791,
#  'delivering': 792,
#  'honestly': 793,
#  'unpredictable': 794,
#  'badly': 795,
#  'parents': 796,
#  'alexander': 797,
#  'artist': 798,
#  's': 799,
#  'gonna': 800,
#  'business': 801,
#  'needed': 802,
#  'mouth': 803,
#  'run': 804,
#  'superbly': 805,
#  'turned': 806,
#  'b': 807,
#  'list': 808,
#  'checking': 809,
#  'problem': 810,
#  'heaven': 811,
#  'lives': 812,
#  'church': 813,
#  'uplifting': 814,
#  'frankly': 815,
#  'lane': 816,
#  'chick': 817,
#  'disappointing': 818,
#  'lousy': 819,
#  'bring': 820,
#  'fresh': 821,
#  'bold': 822,
#  'helps': 823,
#  'idiot': 824,
#  'occupied': 825,
#  'instead': 826,
#  'accused': 827,
#  'edge': 828,
#  'somewhat': 829,
#  'afraid': 830,
#  'advise': 831,
#  'tremendously': 832,
#  'sandra': 833,
#  'bullock': 834,
#  'supposedly': 835,
#  'several': 836,
#  'moments': 837,
#  'need': 838,
#  'friends': 839,
#  'disappointment': 840,
#  'cannot': 841,
#  'stand': 842,
#  'losing': 843,
#  'putting': 844,
#  'ratings': 845,
#  'dramatic': 846,
#  'tension': 847,
#  'central': 848,
#  'themes': 849,
#  'handled': 850,
#  'pictures': 851,
#  'flawed': 852,
#  'core': 853,
#  'following': 854,
#  'bunch': 855,
#  'high': 856,
#  'hell': 857,
#  'viewing': 858,
#  'disaster': 859,
#  'paid': 860,
#  'quinn': 861,
#  'crazy': 862,
#  'hate': 863,
#  'yeah': 864,
#  'girlfriend': 865,
#  'disliked': 866,
#  'five': 867,
#  'mad': 868,
#  '50': 869,
#  'cardboard': 870,
#  'predictably': 871,
#  'crafted': 872,
#  'depressing': 873,
#  'racism': 874,
#  'took': 875,
#  'redeeming': 876,
#  'appalling': 877,
#  'setting': 878,
#  'charisma': 879,
#  'explanation': 880,
#  'era': 881,
#  'wanted': 882,
#  'missed': 883,
#  'step': 884,
#  'freedom': 885,
#  'below': 886,
#  'received': 887,
#  'wayne': 888,
#  'industry': 889,
#  'noteworthy': 890,
#  'blood': 891,
#  'jamie': 892,
#  'genius': 893,
#  'owned': 894,
#  'daughter': 895,
#  'material': 896,
#  'goes': 897,
#  'hence': 898,
#  'machine': 899,
#  'flaws': 900,
#  'mishima': 901,
#  'uninteresting': 902,
#  'chilly': 903,
#  'schrader': 904,
#  'recently': 905,
#  'struck': 906,
#  'contained': 907,
#  'realistic': 908,
#  'lacked': 909,
#  'talent': 910,
#  "director's": 911,
#  'chance': 912,
#  'master': 913,
#  'thrilled': 914,
#  'senses': 915,
#  'deeply': 916,
#  'june': 917,
#  'considering': 918,
#  'offers': 919,
#  'mexican': 920,
#  'matter': 921,
#  'noir': 922,
#  'complex': 923,
#  'psychological': 924,
#  'soul': 925,
#  'water': 926,
#  'gripping': 927,
#  'control': 928,
#  'disturbing': 929,
#  'jerky': 930,
#  'camerawork': 931,
#  'sick': 932,
#  'summary': 933,
#  "weren't": 934,
#  'witty': 935,
#  'above': 936,
#  'ceases': 937,
#  'directors': 938,
#  'visually': 939,
#  'spoiler': 940,
#  'remaining': 941,
#  'suffering': 942,
#  'smile': 943,
#  'literally': 944,
#  '25': 945,
#  'unfolds': 946,
#  'leaves': 947,
#  'room': 948,
#  'contrast': 949,
#  'sublime': 950,
#  '5': 951,
#  'offensive': 952,
#  'poetry': 953,
#  'reviewer': 954,
#  'masterful': 955,
#  'pitiful': 956,
#  'nature': 957,
#  'female': 958,
#  'nuts': 959,
#  'dangerous': 960,
#  'reactions': 961,
#  'twist': 962,
#  'shed': 963,
#  'forget': 964,
#  'underneath': 965,
#  'call': 966,
#  'assistant': 967,
#  'laugh': 968,
#  'de': 969,
#  'cute': 970,
#  'guy': 971,
#  "he's": 972,
#  'taped': 973,
#  'likes': 974,
#  'wholesome': 975,
#  'ways': 976,
#  'portraying': 977,
#  'pleased': 978,
#  'modern': 979,
#  'taking': 980,
#  'towards': 981,
#  'attempts': 982,
#  'supposed': 983,
#  'light': 984,
#  'situation': 985,
#  'leave': 986,
#  'bear': 987,
#  'kinda': 988,
#  'question': 989,
#  'lucy': 990,
#  'wonder': 991,
#  'composition': 992,
#  'brian': 993,
#  'son': 994,
#  'member': 995,
#  'identify': 996,
#  "huston's": 997,
#  'steve': 998,
#  'robert': 999,
#  'father': 1000,
#  ...}

# %%
X[0]
# Out:
# 'A very, very, very slow-moving, aimless movie about a distressed, drifting young man.  '

# %%
tokens = tokenizer.texts_to_sequences(X)
tokens[0]
# Out:
# [3, 28, 28, 28, 287, 407, 1216, 12, 37, 3, 1217, 1218, 408, 143]

# %%
sentence_length = [len(x) for x in tokens]

min(sentence_length), max(sentence_length)
# Out:
# (1, 1400)

# %%
from collections import Counter
Counter(sentence_length)
# Out:
# Counter({14: 23,
#          18: 18,
#          29: 7,
#          8: 37,
#          21: 21,
#          20: 30,
#          3: 24,
#          15: 30,
#          10: 30,
#          6: 38,
#          11: 47,
#          4: 26,
#          16: 34,
#          25: 14,
#          17: 21,
#          872: 1,
#          12: 42,
#          5: 36,
#          19: 21,
#          24: 15,
#          34: 8,
#          7: 35,
#          23: 12,
#          9: 37,
#          2: 12,
#          13: 25,
#          26: 6,
#          1: 3,
#          37: 2,
#          22: 14,
#          27: 8,
#          35: 4,
#          200: 1,
#          1400: 1,
#          45: 4,
#          28: 7,
#          302: 1,
#          43: 2,
#          31: 8,
#          55: 1,
#          44: 2,
#          33: 10,
#          36: 5,
#          69: 1,
#          57: 1,
#          32: 3,
#          30: 6,
#          73: 1,
#          47: 1,
#          38: 3,
#          39: 1,
#          53: 1,
#          51: 1,
#          42: 2,
#          802: 1})

# %%
padded_tokens = pad_sequences(tokens, maxlen=50)

# %%
embedding_index = {}
f = open('./dataset/dataset/glove.6B.200d.txt', encoding='UTF-8')
for line in f:
    values = line.split()
    word = values[0]
    coef = np.asarray(values[1:], dtype= 'float32')
    embedding_index[word]= coef
f.close()

# %%
embedding_index['nepal']
# Out:
# array([ 0.020101 ,  0.41544  , -0.27556  ,  0.63967  ,  0.13188  ,
#        -0.077937 ,  0.045322 , -0.23615  , -0.38871  , -0.24816  ,
#        -0.11325  ,  0.62334  , -0.0043612,  0.095859 , -0.36703  ,
#        -0.097942 , -0.028298 ,  0.17543  , -0.61044  ,  0.0072222,
#         0.65129  ,  2.5718   , -0.45644  ,  0.51435  ,  0.33696  ,
#        -0.41476  , -0.049719 ,  1.5525   ,  0.2805   ,  0.89074  ,
#        -0.068298 , -0.86965  , -0.1083   ,  0.20397  , -0.28714  ,
#        -0.0095998, -0.06447  , -0.046072 , -0.16697  ,  0.23467  ,
#        -0.14176  ,  0.4919   ,  0.38737  , -0.13118  , -0.16852  ,
#        -0.087953 , -0.27169  , -0.27162  , -0.46881  , -0.76117  ,
#         0.10411  , -0.29944  , -0.088991 , -0.71948  , -0.23261  ,
#         0.18182  , -0.16252  , -0.93978  ,  0.033649 ,  0.72291  ,
#         0.46839  ,  0.30018  ,  0.47769  ,  1.3974   ,  0.057041 ,
#         0.16294  , -0.3421   ,  0.069266 , -0.65844  , -0.90702  ,
#        -0.48365  , -0.28711  , -0.22239  ,  0.91995  , -0.040081 ,
#         0.84379  ,  0.62491  ,  0.14794  ,  0.10932  , -0.030779 ,
#         0.067304 ,  0.083222 , -1.3096   ,  0.28988  ,  0.33883  ,
#        -0.36226  , -0.42755  ,  0.34436  ,  0.52775  ,  0.44263  ,
#        -1.0697   , -0.75034  , -0.43278  , -0.97959  , -0.33803  ,
#        -0.22534  , -0.21308  , -0.32521  ,  0.60848  , -0.080946 ,
#        -0.18827  ,  0.22593  ,  0.35257  ,  0.30457  ,  0.07009  ,
#        -0.50206  , -0.46619  , -0.86362  , -0.41464  , -0.59457  ,
#        -0.86337  , -0.95378  ,  0.52451  ,  0.28926  , -0.70079  ,
#        -0.21251  ,  0.2991   ,  0.31288  , -0.46742  ,  0.22327  ,
#        -0.42826  ,  0.0098514,  0.56587  ,  0.37849  ,  0.98499  ,
#        -0.60086  , -0.34412  , -0.39344  , -0.42075  , -0.10732  ,
#         0.72992  ,  0.42042  , -0.40828  ,  0.29609  ,  0.22434  ,
#        -0.043729 ,  0.24343  ,  0.51369  ,  0.17157  , -0.82789  ,
#        -0.051674 ,  0.063003 ,  0.49311  , -0.65052  ,  0.22164  ,
#         0.18221  , -0.10635  , -0.12194  , -0.31167  , -0.2323   ,
#         0.65692  , -0.2434   ,  0.098784 ,  0.26951  ,  0.45161  ,
#        -0.29876  , -0.17174  ,  0.21009  , -0.70927  , -0.48442  ,
#        -0.15398  ,  0.22373  , -0.39866  , -0.47352  , -0.35321  ,
#         0.27524  , -0.15381  , -0.091026 , -0.1432   ,  0.50806  ,
#        -0.086048 ,  0.32905  , -0.033349 , -0.25747  ,  0.55449  ,
#         0.35675  , -0.32052  , -0.1599   , -0.18576  , -0.70944  ,
#         0.47344  ,  0.48815  ,  0.23082  ,  0.1      , -0.62395  ,
#         0.31628  ,  0.47207  ,  1.2326   , -0.12135  , -0.47975  ,
#         0.20285  , -0.22814  ,  0.5281   ,  0.51949  ,  0.079128 ,
#         0.32757  ,  0.67192  , -0.36338  , -1.0273   ,  0.1727   ],
#       dtype=float32)

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 200))

# %%
embedding_matrix.shape
# Out:
# (3134, 200)

# %%
for word in word_index.items():
    word, i = word
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i-1] = embedding_vector

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dropout, Dense, Conv1D, MaxPool1D #lstm preserve the previous data
from keras.optimizers import Adam

# %%
rnn = Sequential()
rnn.add(Embedding(input_dim= vocab_size + 1,
                  output_dim = 200,
                  input_length= 50, weights= [embedding_matrix],
                  trainable = False
                 ))
rnn.add(Conv1D(filters=50, kernel_size=3, activation='relu'))
rnn.add(MaxPool1D())
rnn.add(LSTM(units= 50, activation='relu'))
rnn.add(Dense(units=20, activation='relu'))
rnn.add(Dense(units=1, activation='sigmoid'))

rnn.compile(loss= 'binary_crossentropy', optimizer= Adam(learning_rate= 1e-6), metrics=['acc'])

# %%
rnn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 200)           626800
#
#  conv1d_3 (Conv1D)           (None, 48, 50)            30050
#
#  max_pooling1d_3 (MaxPoolin  (None, 24, 50)            0
#  g1D)
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense_4 (Dense)             (None, 20)                1020
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 678091 (2.59 MB)
# Trainable params: 51291 (200.36 KB)
# Non-trainable params: 626800 (2.39 MB)
# _________________________________________________________________

# %%
rnn.fit(padded_tokens, y, epochs= 20, validation_split=0.15)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 2s 23ms/step - loss: 0.6960 - acc: 0.5024 - val_loss: 0.7141 - val_acc: 0.3482
# Epoch 2/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6959 - acc: 0.5024 - val_loss: 0.7138 - val_acc: 0.3482
# Epoch 3/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6958 - acc: 0.4976 - val_loss: 0.7135 - val_acc: 0.3482
# Epoch 4/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6958 - acc: 0.4976 - val_loss: 0.7131 - val_acc: 0.3482
# Epoch 5/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6957 - acc: 0.4992 - val_loss: 0.7130 - val_acc: 0.3482
# Epoch 6/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6956 - acc: 0.4992 - val_loss: 0.7127 - val_acc: 0.3482
# Epoch 7/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6956 - acc: 0.4992 - val_loss: 0.7126 - val_acc: 0.3482
# Epoch 8/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6955 - acc: 0.4992 - val_loss: 0.7123 - val_acc: 0.3482
# Epoch 9/20
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6954 - acc: 0.5008 - val_loss: 0.7121 - val_acc: 0.3482
# Epoch 10/20
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6954 - acc: 0.5024 - val_loss: 0.7119 - val_acc: 0.3482
# Epoch 11/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6953 - acc: 0.4992 - val_loss: 0.7117 - val_acc: 0.3482
# Epoch 12/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6952 - acc: 0.4992 - val_loss: 0.7115 - val_acc: 0.3482
# Epoch 13/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6952 - acc: 0.4961 - val_loss: 0.7113 - val_acc: 0.3571
# Epoch 14/20
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6951 - acc: 0.4976 - val_loss: 0.7111 - val_acc: 0.3571
# Epoch 15/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6950 - acc: 0.4976 - val_loss: 0.7109 - val_acc: 0.3571
# Epoch 16/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6950 - acc: 0.4992 - val_loss: 0.7107 - val_acc: 0.3571
# Epoch 17/20
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6949 - acc: 0.4992 - val_loss: 0.7105 - val_acc: 0.3571
# Epoch 18/20
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6949 - acc: 0.4976 - val_loss: 0.7103 - val_acc: 0.3571
# Epoch 19/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6948 - acc: 0.4961 - val_loss: 0.7101 - val_acc: 0.3571
# Epoch 20/20
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6948 - acc: 0.4961 - val_loss: 0.7100 - val_acc: 0.3571
